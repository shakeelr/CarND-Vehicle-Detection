# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import time
import sklearn
from skimage.feature import hog
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.ndimage.measurements import label
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda, Cropping2D, BatchNormalization, Dropout, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.callbacks import ModelCheckpoint  
from math import sqrt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Import data and Visualize the data

# %%
# Import car and non car images to train classifiers
cars = glob.glob('./vehicles/*/*.png')
notcars = glob.glob('./non-vehicles/*/*.png')

car_img = []
notcar_img = []
y = []
X_path = []

for car in cars:
#    image = mpimg.imread(car)
#    car_img.append(image)
    y.append(1)
    X_path.append(car)

for notcar in notcars:
#    image = mpimg.imread(notcar)
#    notcar_img.append(image)
    y.append(0)
    X_path.append(notcar)

X_path, y = sklearn.utils.shuffle(X_path,y)
labels = {0: "Not car", 1: "Car"}

# %%
# Visualize the data
fig, axs = plt.subplots(4,8, figsize=(16, 8))
axs = axs.ravel()

for i in range(32):
    image = mpimg.imread(X_path[i])
    axs[i].axis('off')
    axs[i].set_title(labels[y[i]])
    axs[i].imshow(image)

# %% [markdown]
# ## Define a function to preprocess images - convert to grayscale, normalize, and zero center

# %%
def preprocess(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = img[:, :, np.newaxis]
    img = np.divide(img,np.max(img)/2)
    img[:,:,0] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    #img[:,:,1] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    #img[:,:,2] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    return(img)

# %% [markdown]
# ## Define generator function and prepare samples for training

# %%
def generator(samples, batch_size=512):
    n_samples = len(samples)
    while 1: # Loop forever so the generator never terminates
        #sklearn.utils.shuffle(samples)
        for offset in range(0, n_samples, batch_size):
            batch_samples = samples[offset:offset + batch_size]
            x_Train = []
            y_Train = []
            for batch_sample in batch_samples:
                x = mpimg.imread(batch_sample[0])
                x = preprocess(x)
                #x = cv2.cvtColor(x, cv2.COLOR_RGB2GRAY)
                #x = np.divide(x,128)
                #x = x[:, :, np.newaxis]
                #x[:,:,0] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x[:,:,1] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x[:,:,2] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x_flip = cv2.flip(x,1)
                #x = cv2.equalizeHist(x)
                #x_flip = x_flip[:, :, np.newaxis]
                y = float(batch_sample[1])
                x_Train.append(x)
                y_Train.append(y)
                #x_Train.append(x_flip)
                #y_Train.append(y)
            x_Train = np.array(x_Train)
            #y_Train = y_Train
            yield sklearn.utils.shuffle(x_Train, y_Train)

# %%
samples = [(X_path[i], y[i]) for i in range(len(X_path))]
#print(samples[4])
train_samples, valid_samples = train_test_split(samples, test_size=0.20)
train_generator = generator(train_samples, batch_size=512)
valid_generator = generator(valid_samples, batch_size=512)

# %% [markdown]
# # Define CNN model

# %%
model = Sequential()
# Center and normalize our data
#model.add(Lambda(lambda x: x, input_shape=(64,64,1), output_shape=(64,64,1)))

model.add(Convolution2D(32,5,5,subsample=(2,2),  input_shape=(64,64,1)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Convolution2D(64,3,3,subsample=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Convolution2D(128,3,3,subsample=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

#model.add(Convolution2D(128,3,3,subsample=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
#model.add(Activation('relu'))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(100))
#model.add(BatchNormalization())
model.add(Activation('relu'))

#model.add(Dense(50))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
#model.add(Activation('relu'))

model.add(Dense(10))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_13 (Convolution2D) (None, 30, 30, 32)    832         convolution2d_input_5[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 30, 30, 32)    0           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 14, 14, 64)    18496       activation_25[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 14, 14, 64)    0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 6, 6, 128)     73856       activation_26[0][0]
# ____________________________________________________________________________________________________
# activation_27 (Activation)       (None, 6, 6, 128)     0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# flatten_5 (Flatten)              (None, 4608)          0           activation_27[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 4608)          0           flatten_5[0][0]
# ____________________________________________________________________________________________________
# dense_13 (Dense)                 (None, 100)           460900      dropout_5[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, 100)           0           dense_13[0][0]
# ____________________________________________________________________________________________________
# dense_14 (Dense)                 (None, 10)            1010        activation_28[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, 10)            0           dense_14[0][0]
# ____________________________________________________________________________________________________
# dense_15 (Dense)                 (None, 1)             11          activation_29[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, 1)             0           dense_15[0][0]
# ====================================================================================================
# Total params: 555,105
# Trainable params: 555,105
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %% [markdown]
# ## Train the model

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='weights.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

# %%
history_object = model.fit_generator(train_generator, samples_per_epoch=len(train_samples), validation_data=valid_generator, 
                    nb_val_samples=len(valid_samples), nb_epoch=60, callbacks=[checkpointer])
# Out:
# Epoch 1/60
# 13696/14208 [===========================>..] - ETA: 2s - loss: 0.1616 - acc: 0.7649Epoch 00000: val_acc improved from -inf to 0.88598, saving model to weights.hdf5
# 14208/14208 [==============================] - 83s - loss: 0.1589 - acc: 0.7688 - val_loss: 0.0880 - val_acc: 0.8860
# Epoch 2/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0762 - acc: 0.8977Epoch 00001: val_acc improved from 0.88598 to 0.91695, saving model to weights.hdf5
# 14208/14208 [==============================] - 67s - loss: 0.0756 - acc: 0.8986 - val_loss: 0.0629 - val_acc: 0.9169
# Epoch 3/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0578 - acc: 0.9226Epoch 00002: val_acc improved from 0.91695 to 0.92905, saving model to weights.hdf5
# 14208/14208 [==============================] - 68s - loss: 0.0577 - acc: 0.9230 - val_loss: 0.0538 - val_acc: 0.9291
# Epoch 4/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0466 - acc: 0.9395Epoch 00003: val_acc improved from 0.92905 to 0.94032, saving model to weights.hdf5
# 14208/14208 [==============================] - 68s - loss: 0.0465 - acc: 0.9398 - val_loss: 0.0445 - val_acc: 0.9403
# Epoch 5/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0406 - acc: 0.9475Epoch 00004: val_acc improved from 0.94032 to 0.94848, saving model to weights.hdf5
# 14208/14208 [==============================] - 68s - loss: 0.0405 - acc: 0.9476 - val_loss: 0.0397 - val_acc: 0.9485
# Epoch 6/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0348 - acc: 0.9552Epoch 00005: val_acc improved from 0.94848 to 0.95298, saving model to weights.hdf5
# 14208/14208 [==============================] - 69s - loss: 0.0347 - acc: 0.9552 - val_loss: 0.0361 - val_acc: 0.9530
# Epoch 7/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0290 - acc: 0.9636Epoch 00006: val_acc improved from 0.95298 to 0.95890, saving model to weights.hdf5
# 14208/14208 [==============================] - 69s - loss: 0.0289 - acc: 0.9638 - val_loss: 0.0321 - val_acc: 0.9589
# Epoch 8/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.
val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0018 - acc: 0.9981 - val_loss: 0.0140 - val_acc: 0.9834
# Epoch 54/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0020 - acc: 0.9976Epoch 00053: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0020 - acc: 0.9975 - val_loss: 0.0146 - val_acc: 0.9823
# Epoch 55/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0017 - acc: 0.9982Epoch 00054: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0132 - val_acc: 0.9837
# Epoch 56/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0021 - acc: 0.9978Epoch 00055: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0020 - acc: 0.9978 - val_loss: 0.0126 - val_acc: 0.9851
# Epoch 57/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0020 - acc: 0.9979Epoch 00056: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0019 - acc: 0.9980 - val_loss: 0.0132 - val_acc: 0.9842
# Epoch 58/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0017 - acc: 0.9982Epoch 00057: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0016 - acc: 0.9983 - val_loss: 0.0148 - val_acc: 0.9825
# Epoch 59/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0018 - acc: 0.9977Epoch 00058: val_acc did not improve
# 14208/14208 [==============================] - 67s - loss: 0.0018 - acc: 0.9977 - val_loss: 0.0127 - val_acc: 0.9848
# Epoch 60/60
# 13696/14208 [===========================>..] - ETA: 1s - loss: 0.0016 - acc: 0.9982Epoch 00059: val_acc did not improve
# 14208/14208 [==============================] - 71s - loss: 0.0016 - acc: 0.9982 - val_loss: 0.0147 - val_acc: 0.9809

# %%
model.load_weights('weights.hdf5')
model.save('model.h5')

# %% [markdown]
# ## Define prediction function to get predictions from a list of images using the trained model

# %%
def predict(img_list, model):
    images = []
    for img in img_list: 
        x = preprocess(img)
        images.append(x)
    images = np.array(images)
    predictions = model.predict(images)
    predictions = np.rint(predictions)
        
    return predictions

# %%
test_images = [mpimg.imread(X_path[np.random.randint(0, len(X_path))]) for i in range(20)]
#test_image1 = mpimg.imread(X_path[np.random.randint(0, len(X_path))])
#test_image1 = preprocess(test_image)
#test_image2 = mpimg.imread(X_path[np.random.randint(0, len(X_path))])
#test_image2 = preprocess(test_image)
#test_images = [test_image1, test_image2] 
#plt.imshow(test_image.squeeze())
#test_label = model.predict([test_images])
#print(test_labels)
#np.shape(test_images)
predicted = predict(test_images, model)

fig, axs = plt.subplots(4,5, figsize=(16, 8))
axs = axs.ravel()

for i in range(20):
    image = test_images[i]
    axs[i].axis('off')
    axs[i].set_title(predicted[i])
    axs[i].imshow(image)

# %% [markdown]
# ## Sliding window search implementation

# %%
# Define a get windows function to get a sliding set of windows according to a y value
def get_windows(img, y, scale, vis=False):
    imshape = img.shape
    image = cv2.resize(img, (np.int(imshape[1]/scale), np.int(imshape[0]/scale)))
    draw_img = np.copy(image)
    x_pixels = imshape[1]/scale
    window_size = 64
    overlap = 4
    n_windows = int(x_pixels/window_size*overlap)
    windows = []
    boxes = []
    x=0
    y=int(y/scale)
    for i in range(n_windows):
        window = np.array(image[y:y+64,x:x+64,:])
        if vis:
            cv2.rectangle(draw_img, (x,y), (x+64,y+64), (0, 0, 255), 3)
        if np.shape(window) == (64, 64, 3):
            windows.append(window)
            boxes.append([(int(x*scale),int(y*scale)),(int((x+64)*scale),int((y+64)*scale))])
        x=x+int(64/overlap)
    if vis:
        plt.imshow(draw_img)
    return(windows, boxes)

# %% [markdown]
# ## Test Classifer on sliding window

# %%
test_img = mpimg.imread('./test_images/test1.jpg')
windows, boxes = get_windows(test_img, 368, 2, vis=True)
predictions = predict(windows, model)

fig, axs = plt.subplots(6,10, figsize=(20, 8))
axs = axs.ravel()
#print(boxes)

for i in range(60):
    axs[i].axis('off')
    if i < len(windows):
        axs[i].set_title(predictions[i])
        axs[i].imshow(windows[i])

# %% [markdown]
# ## Draw hitboxes

# %%
test_img = mpimg.imread('./test_images/test3.jpg')

window_dict = {0: [400,1,1],
              1: [416,1,1],
              2: [432,1,1],
              3: [448,1,1],
              4: [464,1,1],
              5: [480,1,1],
              6: [496,1,1],
              7: [400,1.5,2],
              8: [424,1.5,2],
              9: [448,1.5,2],
              10: [472,1.5,2],
              11: [496,1.5,2],
              12: [520,1.5,2],
              13: [544,1.5,2],
              14: [400,2,2],
              15: [432,2,2],
              16: [464,2,2],
              17: [496,2,2],
              18: [528,2,2],
              19: [384,1,1],
              20: [376,1.5,1],
              21: [368,2.5,1]}
              #22: [520,2.5,1],
              #23: [560,2.5,1],
              #24: [400,3,1],
              #25: [464,3,1],
              #26: [528,3,1]}
windows = []
boxes = []
weights = []
window_count = 0
for i in range(len(window_dict)):
    windows_i, boxes_i = get_windows(test_img, window_dict[i][0], window_dict[i][1], vis=False)
    window_count += len(windows_i)
    for window in windows_i:
        windows.append(window)
    for box in boxes_i:
        boxes.append(box)
        weights.append(window_dict[i][2])

window_predictions = predict(windows, model)

hits = []
draw_img = np.copy(test_img)

for i in range(len(window_predictions)):
    if window_predictions[i]:
        cv2.rectangle(draw_img, boxes[i][0], boxes[i][1], (0, 0, 255), 3)
        hits.append([boxes[i], weights[i]])


plt.figure(figsize=(20, 8))
plt.imshow(draw_img)
print(np.shape(draw_img))
# Out:
# (720, 1280, 3)

# %% [markdown]
# ## Heatmap

# %%
heatmap = np.zeros_like(test_img[:,:,0])
for hit_box in hits:
    heatmap[hit_box[0][0][1]:hit_box[0][1][1], hit_box[0][0][0]:hit_box[0][1][0]] += int(1*sqrt(hit_box[1])*2)
    
plt.figure(figsize=(20, 8))
plt.imshow(heatmap)
print(np.max(heatmap))
# Out:
# 18

# %% [markdown]
# # Thresholding

# %%
threshold = 8
heatmap[heatmap <= threshold] = 0
plt.figure(figsize=(20, 8))
plt.imshow(heatmap)
labels = label(heatmap)
print(labels[1], 'cars in image')
# Out:
# 1 cars in image

# %% [markdown]
# ## Detect cars

# %%
draw_img = np.copy(test_img)

for car in range(1, labels[1]+1):
    nonzero = (labels[0] == car).nonzero()
    # Identify x and y values of those pixels
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Define a bounding box based on min/max x and y
    bbox = [(np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy))]
    cv2.rectangle(draw_img, bbox[0], bbox[1], (0, 0, 255), 3)

plt.imshow(draw_img)

# %%
class Heatmap():
    def __init__(self):
        self.recent_heatmaps = [] 
        # n most recent heatmaps added together
        self.added_heatmap = np.zeros((720, 1280), dtype=int)

# %% [markdown]
# ## Full pipeline implementation

# %%
heatmap = Heatmap()

window_dict = {0: [400,1,1],
              1: [416,1,1],
              2: [432,1,1],
              3: [448,1,1],
              4: [464,1,1],
              5: [480,1,1],
              6: [496,1,1],
              7: [400,1.5,2],
              8: [424,1.5,2],
              9: [448,1.5,2],
              10: [472,1.5,2],
              11: [496,1.5,2],
              12: [520,1.5,2],
              13: [544,1.5,2],
              14: [400,2,2],
              15: [432,2,2],
              16: [464,2,2],
              17: [496,2,2],
              18: [528,2,2],
              19: [384,1,1],
              20: [376,1.5,1],
              21: [368,2.5,1]}

def process_image(img):
    
    global model
    global window_dict
    global heatmap
    
    windows = []
    boxes = []
    weights = []
    window_count = 0
    n = 8
    threshold = 8
    
    for i in range(len(window_dict)):
        windows_i, boxes_i = get_windows(img, window_dict[i][0], window_dict[i][1], vis=False)
        window_count += len(windows_i)
        for window in windows_i:
            windows.append(window)
        for box in boxes_i:
            boxes.append(box)
            weights.append(window_dict[i][2])

    window_predictions = predict(windows, model)

    hits = []

    for i in range(len(window_predictions)):
        if window_predictions[i]:
            hits.append([boxes[i], weights[i]])
            
    heatmap_img = np.zeros_like(img[:,:,0])
    
    for hit_box in hits:
        heatmap_img[hit_box[0][0][1]:hit_box[0][1][1], hit_box[0][0][0]:hit_box[0][1][0]] += hit_box[1]
        
    heatmap.recent_heatmaps.append(heatmap_img)
    heatmap.added_heatmap = np.add(heatmap.added_heatmap, heatmap_img)
    
    if len(heatmap.recent_heatmaps) >= n:
        oldest_heatmap = heatmap.recent_heatmaps.pop(0)
        heatmap.added_heatmap = np.subtract(heatmap.added_heatmap,oldest_heatmap)
    
    heatmap_thresholded = np.copy(heatmap.added_heatmap)
    heatmap_thresholded[heatmap_thresholded <= threshold*len(heatmap.recent_heatmaps)] = 0
    
    labels = label(heatmap_thresholded)
    
    draw_img = np.copy(img)
    
    for car in range(1, labels[1]+1):
        nonzero = (labels[0] == car).nonzero()
        # Identify x and y values of those pixels
        nonzeroy = np.array(nonzero[0])
        nonzerox = np.array(nonzero[1])
        # Define a bounding box based on min/max x and y
        bbox = [(np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy))]
        cv2.rectangle(draw_img, bbox[0], bbox[1], (0, 0, 255), 3)

    return(draw_img)

# %%
# Make a list of test images# Make  
test_image_names = glob.glob('./test_images/test*.jpg')
test_images = []

# Step through the list and search for chessboard corners
for fname in test_image_names:
    img = mpimg.imread(fname)
    test_images.append(img)
    
# Visualize the data
fig, axs = plt.subplots(2,3, figsize=(16, 8))
axs = axs.ravel()

for i in range(6):
    axs[i].axis('off')
    heatmap = Heatmap()
    axs[i].imshow(process_image(test_images[i]))

#draw_img = process_image(test_images[0])
#plt.imshow(draw_img)

# %% [markdown]
# ## Test on video

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
heatmap = Heatmap()
video_output  = "output_videos\project_video.mp4"
clip = VideoFileClip('.\project_video.mp4')
processed_clip = clip.fl_image(process_image)
# %time processed_clip.write_videofile(video_output, audio=False)
# Out:
# [MoviePy] >>>> Building video output_videos\project_video.mp4
# [MoviePy] Writing video output_videos\project_video.mp4
# 100%|█████████████████████████████████████▉| 1260/1261 [27:36<00:01,  1.31s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: output_videos\project_video.mp4
#
# Wall time: 27min 37s
