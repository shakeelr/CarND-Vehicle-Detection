# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import time
import sklearn
from skimage.feature import hog
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.ndimage.measurements import label
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda, Cropping2D, BatchNormalization, Dropout, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.callbacks import ModelCheckpoint  
from math import sqrt

# %%
# Import car and non car images to train classifiers
cars = glob.glob('./vehicles/*/*.png')
notcars = glob.glob('./non-vehicles/*/*.png')

car_img = []
notcar_img = []
y = []
X_path = []

for car in cars:
#    image = mpimg.imread(car)
#    car_img.append(image)
    y.append(1)
    X_path.append(car)

for notcar in notcars:
#    image = mpimg.imread(notcar)
#    notcar_img.append(image)
    y.append(0)
    X_path.append(notcar)

X_path, y = sklearn.utils.shuffle(X_path,y)
labels = {0: "Not car", 1: "Car"}

# %%
def preprocess(img_list):
    preprocessed_img_list = []
    for img_path in img_list:
        img = mpimg.imread(img_path)
        #resize
        #img = cv2.resize(img, (32,32))
        #grayscale
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        #img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
        #histogram equalization
        img = cv2.equalizeHist(img)
        #normalize
        img = img[:, :, np.newaxis]
        img = np.divide(img,128)
        #img = np.subtract(img, np.mean(img))
        img[:,:,0] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
        preprocessed_img_list.append(img)
    return preprocessed_img_list

# %%
# Visualize the data
fig, axs = plt.subplots(4,8, figsize=(16, 8))
axs = axs.ravel()

for i in range(32):
    image = mpimg.imread(X_path[i])
    axs[i].axis('off')
    axs[i].set_title(labels[y[i]])
    axs[i].imshow(image)

# %%
def preprocess(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = img[:, :, np.newaxis]
    img = np.divide(img,np.max(img)/2)
    #img[:,:,0] = np.divide(img[:,:,0],np.max(img[:,:,0]))
    img[:,:,0] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    #img[:,:,1] = np.divide(img[:,:,0],np.max(img[:,:,0]))
    #img[:,:,1] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    #img[:,:,2] = np.divide(img[:,:,0],np.max(img[:,:,0]))
    #img[:,:,2] = np.subtract(img[:,:,0],np.mean(img[:,:,0]))
    return(img)

# %%
def generator(samples, batch_size=512):
    n_samples = len(samples)
    while 1: # Loop forever so the generator never terminates
        #sklearn.utils.shuffle(samples)
        for offset in range(0, n_samples, batch_size):
            batch_samples = samples[offset:offset + batch_size]
            x_Train = []
            y_Train = []
            for batch_sample in batch_samples:
                x = mpimg.imread(batch_sample[0])
                x = preprocess(x)
                #x = cv2.cvtColor(x, cv2.COLOR_RGB2GRAY)
                #x = np.divide(x,128)
                #x = x[:, :, np.newaxis]
                #x[:,:,0] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x[:,:,1] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x[:,:,2] = np.subtract(x[:,:,0],np.mean(x[:,:,0]))
                #x_flip = cv2.flip(x,1)
                #x = cv2.equalizeHist(x)
                #x_flip = x_flip[:, :, np.newaxis]
                y = float(batch_sample[1])
                x_Train.append(x)
                y_Train.append(y)
                #x_Train.append(x_flip)
                #y_Train.append(y)
            x_Train = np.array(x_Train)
            #y_Train = y_Train
            yield sklearn.utils.shuffle(x_Train, y_Train)

# %%
samples = [(X_path[i], y[i]) for i in range(len(X_path))]
#print(samples[4])
train_samples, valid_samples = train_test_split(samples, test_size=0.20)
train_generator = generator(train_samples, batch_size=512)
valid_generator = generator(valid_samples, batch_size=512)

# %%
#n_samples = 512
#batch_size = 256
#sklearn.utils.shuffle(samples)
#for offset in range(0, n_samples, batch_size):
#    batchSamples = samples[offset:offset + batch_size]
#    x_Train = []
#    y_Train = []
#    for batch_sample in batchSamples:
#        x = preprocess(x)
#        x = cv2.cvtColor(x, cv2.COLOR_RGB2GRAY)
#        x_flip = cv2.flip(x,1)
#        #x = cv2.equalizeHist(x)
#        x = x[:, :, np.newaxis]
#        x_flip = x_flip[:, :, np.newaxis]
#        y = float(batch_sample[1])
#        x_Train.append(x)
#        y_Train.append(y)
#        x_Train.append(x_flip)
#        y_Train.append(y)

#    x_Train = np.array(x_Train)
#    y_Train = np.expand_dims(y_Train, axis=1)
    #yield sklearn.utils.shuffle(x_Train, y_Train)

# %%
model = Sequential()
# Center and normalize our data
#model.add(Lambda(lambda x: x, input_shape=(64,64,1), output_shape=(64,64,1)))

model.add(Convolution2D(32,5,5,subsample=(2,2),  input_shape=(64,64,1)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Convolution2D(64,3,3,subsample=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

#model.add(Convolution2D(64,5,5,subsample=(2,2)))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
#model.add(Activation('relu'))

model.add(Flatten())

model.add(Dense(100))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Dense(50))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Dense(10))
#model.add(BatchNormalization())
#model.add(Dropout(0.9))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_63 (Convolution2D) (None, 30, 30, 32)    832         convolution2d_input_16[0][0]
# ____________________________________________________________________________________________________
# activation_203 (Activation)      (None, 30, 30, 32)    0           convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D) (None, 14, 14, 64)    18496       activation_203[0][0]
# ____________________________________________________________________________________________________
# activation_204 (Activation)      (None, 14, 14, 64)    0           convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# flatten_38 (Flatten)             (None, 12544)         0           activation_204[0][0]
# ____________________________________________________________________________________________________
# dense_149 (Dense)                (None, 100)           1254500     flatten_38[0][0]
# ____________________________________________________________________________________________________
# activation_205 (Activation)      (None, 100)           0           dense_149[0][0]
# ____________________________________________________________________________________________________
# dense_150 (Dense)                (None, 50)            5050        activation_205[0][0]
# ____________________________________________________________________________________________________
# activation_206 (Activation)      (None, 50)            0           dense_150[0][0]
# ____________________________________________________________________________________________________
# dense_151 (Dense)                (None, 10)            510         activation_206[0][0]
# ____________________________________________________________________________________________________
# activation_207 (Activation)      (None, 10)            0           dense_151[0][0]
# ____________________________________________________________________________________________________
# dense_152 (Dense)                (None, 1)             11          activation_207[0][0]
# ____________________________________________________________________________________________________
# activation_208 (Activation)      (None, 1)             0           dense_152[0][0]
# ====================================================================================================
# Total params: 1,279,399
# Trainable params: 1,279,399
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='weights.hdf5', monitor='val_acc', verbose=1, save_best_only=True)

# %%
history_object = model.fit_generator(train_generator, samples_per_epoch=len(train_samples), validation_data=valid_generator, 
                    nb_val_samples=len(valid_samples), nb_epoch=20, callbacks=[checkpointer])
# Out:
# Epoch 1/20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.1489 - acc: 0.7762Epoch 00000: val_acc improved from -inf to 0.88176, saving model to weights.hdf5
# 14208/14208 [==============================] - 84s - loss: 0.1479 - acc: 0.7784 - val_loss: 0.0868 - val_acc: 0.8818
# Epoch 2/20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.
20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.0032 - acc: 0.9970Epoch 00016: val_acc improved from 0.96931 to 0.97016, saving model to weights.hdf5
# 14208/14208 [==============================] - 63s - loss: 0.0031 - acc: 0.9971 - val_loss: 0.0233 - val_acc: 0.9702
# Epoch 18/20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.0022 - acc: 0.9980Epoch 00017: val_acc improved from 0.97016 to 0.97128, saving model to weights.hdf5
# 14208/14208 [==============================] - 64s - loss: 0.0022 - acc: 0.9981 - val_loss: 0.0238 - val_acc: 0.9713
# Epoch 19/20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.0020 - acc: 0.9983Epoch 00018: val_acc improved from 0.97128 to 0.97157, saving model to weights.hdf5
# 14208/14208 [==============================] - 64s - loss: 0.0019 - acc: 0.9983 - val_loss: 0.0248 - val_acc: 0.9716
# Epoch 20/20
# 13824/14208 [============================>.] - ETA: 1s - loss: 0.0018 - acc: 0.9984Epoch 00019: val_acc improved from 0.97157 to 0.97185, saving model to weights.hdf5
# 14208/14208 [==============================] - 64s - loss: 0.0018 - acc: 0.9985 - val_loss: 0.0242 - val_acc: 0.9718

# %%
model.load_weights('weights.hdf5')
model.save('model.h5')

# %%
def predict(img_list, model):
    images = []
    for img in img_list: 
        x = preprocess(img)
        images.append(x)
    images = np.array(images)
    predictions = model.predict(images)
    predictions = np.rint(predictions)
        
    return predictions

# %%
test_images = [mpimg.imread(X_path[np.random.randint(0, len(X_path))]) for i in range(20)]
#test_image1 = mpimg.imread(X_path[np.random.randint(0, len(X_path))])
#test_image1 = preprocess(test_image)
#test_image2 = mpimg.imread(X_path[np.random.randint(0, len(X_path))])
#test_image2 = preprocess(test_image)
#test_images = [test_image1, test_image2] 
#plt.imshow(test_image.squeeze())
#test_label = model.predict([test_images])
#print(test_labels)
#np.shape(test_images)
predicted = predict(test_images, model)

fig, axs = plt.subplots(4,5, figsize=(16, 8))
axs = axs.ravel()

for i in range(20):
    image = test_images[i]
    axs[i].axis('off')
    axs[i].set_title(predicted[i])
    axs[i].imshow(image)

# %%
# Define a get windows function to get a sliding set of windows according to a y value
def get_windows(img, y, scale, vis=False):
    imshape = img.shape
    image = cv2.resize(img, (np.int(imshape[1]/scale), np.int(imshape[0]/scale)))
    draw_img = np.copy(image)
    x_pixels = imshape[1]/scale
    window_size = 64
    overlap = 4
    n_windows = int(x_pixels/window_size*overlap)
    windows = []
    boxes = []
    x=0
    y=int(y/scale)
    for i in range(n_windows):
        window = np.array(image[y:y+64,x:x+64,:])
        if vis:
            cv2.rectangle(draw_img, (x,y), (x+64,y+64), (0, 0, 255), 3)
        if np.shape(window) == (64, 64, 3):
            windows.append(window)
            boxes.append([(int(x*scale),int(y*scale)),(int((x+64)*scale),int((y+64)*scale))])
        x=x+int(64/overlap)
    if vis:
        plt.imshow(draw_img)
    return(windows, boxes)

# %%
test_img = mpimg.imread('./test_images/test1.jpg')
windows, boxes = get_windows(test_img, 528, 3.0, vis=True)
predictions = predict(windows, model)

fig, axs = plt.subplots(4,10, figsize=(20, 8))
axs = axs.ravel()
#print(boxes)

for i in range(40):
    axs[i].axis('off')
    if i < len(windows):
        axs[i].set_title(predictions[i])
        axs[i].imshow(windows[i])

# %%
test_img = mpimg.imread('./test_images/test3.jpg')

window_dict = {0: [400,1],
              1: [416,1],
              2: [432,1],
              3: [448,1],
              4: [464,1],
              5: [480,1],
              6: [496,1],
              7: [400,1.5],
              8: [424,1.5],
              9: [448,1.5],
              10: [472,1.5],
              11: [496,1.5],
              12: [520,1.5],
              13: [544,1.5],
              14: [400,2],
              15: [432,2],
              16: [464,2],
              17: [496,2],
              18: [528,2],
              19: [400,2.5],
              20: [440,2.5],
              21: [480,2.5],
              22: [520,2.5],
              23: [560,2.5],
              24: [400,3],
              25: [464,3],
              26: [528,3]}
windows = []
boxes = []
scales = []
window_count = 0
for i in range(len(window_dict)):
    windows_i, boxes_i = get_windows(test_img, window_dict[i][0], window_dict[i][1], vis=False)
    window_count += len(windows_i)
    for window in windows_i:
        windows.append(window)
    for box in boxes_i:
        boxes.append(box)
        scales.append(window_dict[i][1])

window_predictions = predict(windows, model)

hits = []
draw_img = np.copy(test_img)

for i in range(len(window_predictions)):
    if window_predictions[i]:
        cv2.rectangle(draw_img, boxes[i][0], boxes[i][1], (0, 0, 255), 3)
        hits.append([boxes[i], scales[i]])


plt.figure(figsize=(20, 8))
plt.imshow(draw_img)

# %%
heatmap = np.zeros_like(test_img[:,:,0])
for hit_box in hits:
    heatmap[hit_box[0][0][1]:hit_box[0][1][1], hit_box[0][0][0]:hit_box[0][1][0]] += int(1*sqrt(hit_box[1])*2)
    
plt.figure(figsize=(20, 8))
plt.imshow(heatmap)
print(np.max(heatmap))
# Out:
# 12

# %%
threshold = 6
heatmap[heatmap <= threshold] = 0
plt.figure(figsize=(20, 8))
plt.imshow(heatmap)
labels = label(heatmap)
print(labels[1], 'cars in image')
# Out:
# 1 cars in image

# %%
draw_img = np.copy(test_img)

for car in range(1, labels[1]+1):
    nonzero = (labels[0] == car).nonzero()
    # Identify x and y values of those pixels
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Define a bounding box based on min/max x and y
    bbox = [(np.min(nonzerox), np.min(nonzeroy)), (np.max(nonzerox), np.max(nonzeroy))]
    cv2.rectangle(draw_img, bbox[0], bbox[1], (0, 0, 255), 3)

plt.imshow(draw_img)

# %%
window_dict = {0: [400,1],
              1: [416,1],
              2: [432,1],
              3: [448,1],
              4: [464,1],
              5: [480,1],
              6: [496,1],
              7: [400,1.5],
              8: [424,1.5],
              9: [448,1.5],
              10: [472,1.5],
              11: [496,1.5],
              12: [520,1.5],
              13: [544,1.5],
              14: [400,2],
              15: [432,2],
              16: [464,2],
              17: [496,2],
              18: [528,2],
              19: [400,2.5],
              20: [440,2.5],
              21: [480,2.5],
              22: [520,2.5],
              23: [560,2.5],
              24: [400,3],
              25: [464,3],
              26: [528,3]}

def pipeline(img, model, window_dict):
    
    windows = []
    boxes = []
    scales = []
    window_count = 0
    for i in range(len(window_dict)):
        windows_i, boxes_i = get_windows(img, window_dict[i][0], window_dict[i][1], vis=False)
        window_count += len(windows_i)
        for window in windows_i:
            windows.append(window)
        for box in boxes_i:
            boxes.append(box)
            scales.append(window_dict[i][1])

    window_predictions = predict(windows, model)

    hits = []
    draw_img = np.copy(test_img)

    for i in range(len(window_predictions)):
        if window_predictions[i]:
            cv2.rectangle(draw_img, boxes[i][0], boxes[i][1], (0, 0, 255), 3)
            hits.append([boxes[i], scales[i]])


    plt.figure(figsize=(20, 8))
    plt.imshow(draw_img)
